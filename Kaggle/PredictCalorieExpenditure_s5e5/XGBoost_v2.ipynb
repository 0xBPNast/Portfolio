# %%
import pandas as pd 
import numpy as np 
import time
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from xgboost import XGBRegressor
import warnings
warnings.simplefilter('ignore')

# %%
# Load data
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
submission = pd.read_csv("sample_submission.csv")

# %%
# Add column names for numerical features
numerical_features = ["Age","Height","Weight","Duration","Heart_Rate","Body_Temp"]

# Function to add cross terms i.e. feature1 x feature2 (only for numerical)
def add_feature_cross_terms(df, numerical_features):
    df_new = df.copy()
    
    for i in range(len(numerical_features)):
        for j in range(i + 1, len(numerical_features)):  
            feature1 = numerical_features[i]
            feature2 = numerical_features[j]
            cross_term_name = f"{feature1}_x_{feature2}"
            df_new[cross_term_name] = df_new[feature1] * df_new[feature2]

    return df_new

# Add cross terms to train & test sets
train = add_feature_cross_terms(train, numerical_features)
test = add_feature_cross_terms(test, numerical_features)

# %%
num_features = train.select_dtypes(include='number')

# %%
# Encode non-numerical features
le = LabelEncoder()
train['Sex'] = le.fit_transform(train['Sex'])
test['Sex'] = le.transform(test['Sex'])

train["Sex"] = train["Sex"].astype("category")
test["Sex"] = test["Sex"].astype("category")

X = train.drop(columns=["id", "Calories"])
y = np.log1p(train["Calories"])
X_test = test.drop(columns=["id"])

# %%
FOLDS = 50
FEATURES = X.columns.tolist()

# KFold setup
kf = KFold(n_splits=FOLDS, shuffle=True, random_state=42)

# Arrays to store predictions
oof = np.zeros(len(train))
pred = np.zeros(len(test))

# Start CV loop
for i, (train_idx, valid_idx) in enumerate(kf.split(X, y)):
    print(f"\n{'#'*10} Fold {i+1} {'#'*10}")
    
    x_train = X.iloc[train_idx].copy()
    y_train = y.iloc[train_idx]
    x_valid = X.iloc[valid_idx].copy()
    y_valid = y.iloc[valid_idx]
    x_test = X_test.copy()
    
    start = time.time()

    # Train model
    model = XGBRegressor(
        device="cuda" if XGBRegressor().get_params().get("device") == "cuda" else "cpu",
        max_depth=10,
        colsample_bytree=0.75,
        subsample=0.9,
        n_estimators=2000,
        learning_rate=0.02,
        gamma=0.01, 
        max_delta_step=2,
        early_stopping_rounds=100,
        eval_metric="rmse",
        enable_categorical=True
    )

    model.fit(
        x_train, y_train,
        eval_set=[(x_valid, y_valid)],
        verbose=100
    )

    # Predict OOF and test
    oof[valid_idx] = model.predict(x_valid)
    pred += model.predict(x_test)

    rmse = np.sqrt(mean_squared_error(y_valid, oof[valid_idx]))
    print(f"Fold {i+1} RMSE: {rmse:.4f}")
    print(f"Feature engineering & training time: {time.time() - start:.1f} sec")

# Average test predictions
pred /= FOLDS

# Final RMSE
full_rmse = np.sqrt(mean_squared_error(y, oof))
print(f"\nFinal CV RMSE: {full_rmse:.4f}")
# Out:
# ########## Fold 1 ##########
# [0]	validation_0-rmse:0.95093
# [100]	validation_0-rmse:0.14291
# [200]	validation_0-rmse:0.06515
# [300]	validation_0-rmse:0.06292
# [400]	validation_0-rmse:0.06290
# [416]	validation_0-rmse:0.06290
# Fold 1 RMSE: 0.0629
# Feature engineering & training time: 18.8 sec
#
# ########## Fold 2 ##########
# [0]	validation_0-rmse:0.94321
# [100]	validation_0-rmse:0.14189
# [200]	validation_0-rmse:0.06355
# [300]	validation_0-rmse:0.06105
# [400]	validation_0-rmse:0.06094
# [500]	validation_0-rmse:0.06096
# [541]	validation_0-rmse:0.06095
# Fold 2 RMSE: 0.0609
# Feature engineering & training time: 22.3 sec
#
# ########## Fold 3 ##########
# [0]	validation_0-rmse:0.95574
# [100]	validation_0-rmse:0.14377
# [200]	validation_0-rmse:0.06204
# [300]	validation_0-rmse:0.05893
# [400]	validation_0-rmse:0.05881
# [500]	validation_0-rmse:0.05881
# [524]	validation_0-rmse:0.05881
# Fold 3 RMSE: 0.0588
# Feature engineering & training time: 23.0 sec
#
# ########## Fold 4 ##########
# [0]	validation_0-rmse:0.93257
# [100]	validation_0-rmse:0.13977
# [200]	validation_0-rmse:0.06171
# [300]	validation_0-rmse:0.05910
# [400]	validation_0-rmse:0.05897
# [500]	validation_0-rmse:0.05900
# [526]	validation_0-rmse:0.05902
# Fold 4 RMSE: 0.0590
# Feature engineering & training time: 21.6 sec
#
# ########## Fold 5 ##########
# [0]	validation_0-rmse:0.94866
# [100]	validation_0-rmse:0.14240
# [200]	validation_0-rmse:0.06226
# [300]	validation_0-rmse:0.05930
# [400]	validation_0-rmse:0.05915
# [500]	validation_0-rmse:0.05911
# [600]	validation_0-rmse:0.05911
# [700]	validation_0-rmse:0.05909
# [774]	validation_0-rmse:0.05910
# Fold 5 RMSE: 0.0591
# Feature engineering & training time: 24.2 sec
#
# ########## Fold 6 ##########
# [0]	validation_0-rmse:0.93952
# [100]	validation_0-rmse:0.14033
# [200]	validation_0-rmse:0.06144
# [300]	validation_0-rmse:0.05885
# [400]	validation_0-rmse:0.05877
# [500]	validation_0-rmse:0.05880
# [512]	validation_0-rmse:0.05880
# Fold 6 RMSE: 0.0588
# Feature engineering & training time: 19.5 sec
#
# ########## Fold 7 ##########
# [0]	validation_0-rmse:0.93992
# [100]	validation_0-rmse:0.13988
# [200]	validation_0-rmse:0.06097
# [300]	validation_0-rmse:0.05850
# [400]	validation_0-rmse:0.05849
# [445]	validation_0-rmse:0.05851
# Fold 7 RMSE: 0.0585
# Feature engineering & training time: 19.3 sec
#
# ########## Fold 8 ##########
# [0]	validation_0-rmse:0.95048
# [100]	validation_0-rmse:0.14299
# [200]	validation_0-rmse:0.06256
# [300]	validation_0-rmse:0.05963
# [400]	validation_0-rmse:0.05953
# [500]	validation_0-rmse:0.05951
# [600]	validation_0-rmse:0.05952
# [664]	validation_0-rmse:0.05954
# Fold 8 RMSE: 0.0595
# Feature engineering & training time: 23.5 sec
#
# ########## Fold 9 ##########
# [0]	validation_0-rmse:0.93967
# [100]	validation_0-rmse:0.13954
# [200]	validation_0-rmse:0.06088
# [300]	validation_0-rmse:0.05843
# [400]	validation_0-rmse:0.05834
# [500]	validation_0-rmse:0.05836
# [515]	validation_0-rmse:0.05838
# Fold 9 RMSE: 0.0583
# Feature engineering & training time: 21.1 sec
#
# ########## Fold 10 ##########
# [0]	validation_0-rmse:0.94271
# [100]	validation_0-rmse:0.14082
# [200]	validation_0-rmse:0.06137
# [300]	validation_0-rmse:0.05871
# [400]	validation_0-rmse:0.05859
# [500]	validation_0-rmse:0.05860
# [518]	validation_0-rmse:0.05860
# Fold 10 RMSE: 0.0586
# Feature engineering & training time: 20.7 sec
#
# ########## Fold 11 ##########
# [0]	validation_0-rmse:0.95323
# [100]	validation_0-rmse:0.14179
# [200]	validation_0-rmse:0.06046
# [300]	validation_0-rmse:0.05771
# [400]	validation_0-rmse:0.05762
# [481]	validation_0-rmse:0.05768
# Fold 11 RMSE: 0.0576
# Feature engineering & training time: 19.0 sec
#
# ########## Fold 12 ##########
# [0]	validation_0-rmse:0.94463
# [100]	validation_0-rmse:0.14527
# [200]	validation_0-rmse:0.06940
# [300]	validation_0-rmse:0.06669
# [400]	validation_0-rmse:0.06651
# [500]	validation_0-rmse:0.06648
# [590]	validation_0-rmse:0.06651
# Fold 12 RMSE: 0.0665
# Feature engineering & training time: 21.7 sec
#
# ########## Fold 13 ##########
# [0]	validation_0-rmse:0.95569
# [100]	validation_0-rmse:0.14412
# [200]	validation_0-rmse:0.06521
# [300]	validation_0-rmse:0.06262
# [400]	validation_0-rmse:0.06257
# [496]	validation_0-rmse:0.06257
# Fold 13 RMSE: 0.0626
# Feature engineering & training time: 23.6 sec
#
# ########## Fold 14 ##########
# [0]	validation_0-rmse:0.95194
# [100]	validation_0-rmse:0.14282
# [200]	validation_0-rmse:0.06304
# [300]	validation_0-rmse:0.06024
# [400]	validation_0-rmse:0.06011
# [500]	validation_0-rmse:0.06011
# [566]	validation_0-rmse:0.06013
# Fold 14 RMSE: 0.0601
# Feature engineering & training time: 24.6 sec
#
# ########## Fold 15 ##########
# [0]	validation_0-rmse:0.95268
# [100]	validation_0-rmse:0.14370
# [200]	validation_0-rmse:0.06483
# [300]	validation_0-rmse:0.06224
# [400]	validation_0-rmse:0.06222
# [485]	validation_0-rmse:0.06227
# Fold 15 RMSE: 0.0622
# Feature engineering & training time: 19.9 sec
#
# ########## Fold 16 ##########
# [0]	validation_0-rmse:0.94203
# [100]	validation_0-rmse:0.14281
# [200]	validation_0-rmse:0.06548
# [300]	validation_0-rmse:0.06297
# [400]	validation_0-rmse:0.06279
# [500]	validation_0-rmse:0.06276
# [563]	validation_0-rmse:0.06276
# Fold 16 RMSE: 0.0627
# Feature engineering & training time: 21.4 sec
#
# ########## Fold 17 ##########
# [0]	validation_0-rmse:0.94429
# [100]	validation_0-rmse:0.14192
# [200]	validation_0-rmse:0.06144
# [300]	validation_0-rmse:0.05833
# [400]	validation_0-rmse:0.05819
# [500]	validation_0-rmse:0.05821
# [524]	validation_0-rmse:0.05821
# Fold 17 RMSE: 0.0582
# Feature engineering & training time: 20.5 sec
#
# ########## Fold 18 ##########
# [0]	validation_0-rmse:0.94021
# [100]	validation_0-rmse:0.14043
# [200]	validation_0-rmse:0.06064
# [300]	validation_0-rmse:0.05780
# [400]	validation_0-rmse:0.05763
# [500]	validation_0-rmse:0.05761
# [555]	validation_0-rmse:0.05762
# Fold 18 RMSE: 0.0576
# Feature engineering & training time: 22.9 sec
#
# ########## Fold 19 ##########
# [0]	validation_0-rmse:0.94213
# [100]	validation_0-rmse:0.14022
# [200]	validation_0-rmse:0.06105
# [300]	validation_0-rmse:0.05860
# [400]	validation_0-rmse:0.05856
# [472]	validation_0-rmse:0.05857
# Fold 19 RMSE: 0.0585
# Feature engineering & training time: 19.1 sec
#
# ########## Fold 20 ##########
# [0]	validation_0-rmse:0.94096
# [100]	validation_0-rmse:0.13998
# [200]	validation_0-rmse:0.06049
# [300]	validation_0-rmse:0.05791
# [400]	validation_0-rmse:0.05787
# [495]	validation_0-rmse:0.05789
# Fold 20 RMSE: 0.0579
# Feature engineering & training time: 21.0 sec
#
# ########## Fold 21 ##########
# [0]	validation_0-rmse:0.94837
# [100]	validation_0-rmse:0.14514
# [200]	validation_0-rmse:0.06796
# [300]	validation_0-rmse:0.06528
# [400]	validation_0-rmse:0.06509
# [500]	validation_0-rmse:0.06500
# [588]	validation_0-rmse:0.06500
# Fold 21 RMSE: 0.0650
# Feature engineering & training time: 22.0 sec
#
# ########## Fold 22 ##########
# [0]	validation_0-rmse:0.94379
# [100]	validation_0-rmse:0.14186
# [200]	validation_0-rmse:0.06091
# [300]	validation_0-rmse:0.05792
# [400]	validation_0-rmse:0.05780
# [500]	validation_0-rmse:0.05777
# [600]	validation_0-rmse:0.05779
# [604]	validation_0-rmse:0.05780
# Fold 22 RMSE: 0.0578
# Feature engineering & training time: 23.1 sec
#
# ########## Fold 23 ##########
# [0]	validation_0-rmse:0.95062
# [100]	validation_0-rmse:0.13958
# [200]	validation_0-rmse:0.05807
# [300]	validation_0-rmse:0.05565
# [400]	validation_0-rmse:0.05565
# [500]	validation_0-rmse:0.05566
# [533]	validation_0-rmse:0.05569
# Fold 23 RMSE: 0.0556
# Feature engineering & training time: 20.9 sec
#
# ########## Fold 24 ##########
# [0]	validation_0-rmse:0.94521
# [100]	validation_0-rmse:0.14170
# [200]	validation_0-rmse:0.06343
# [300]	validation_0-rmse:0.06102
# [400]	validation_0-rmse:0.06098
# [441]	validation_0-rmse:0.06100
# Fold 24 RMSE: 0.0610
# Feature engineering & training time: 18.9 sec
#
# ########## Fold 25 ##########
# [0]	validation_0-rmse:0.94320
# [100]	validation_0-rmse:0.13969
# [200]	validation_0-rmse:0.05977
# [300]	validation_0-rmse:0.05735
# [400]	validation_0-rmse:0.05734
# [440]	validation_0-rmse:0.05737
# Fold 25 RMSE: 0.0573
# Feature engineering & training time: 19.5 sec
#
# ########## Fold 26 ##########
# [0]	validation_0-rmse:0.94769
# [100]	validation_0-rmse:0.14245
# [200]	validation_0-rmse:0.06353
# [300]	validation_0-rmse:0.06093
# [400]	validation_0-rmse:0.06084
# [482]	validation_0-rmse:0.06087
# Fold 26 RMSE: 0.0608
# Feature engineering & training time: 21.8 sec
#
# ########## Fold 27 ##########
# [0]	validation_0-rmse:0.93959
# [100]	validation_0-rmse:0.13916
# [200]	validation_0-rmse:0.05793
# [300]	validation_0-rmse:0.05506
# [400]	validation_0-rmse:0.05489
# [500]	validation_0-rmse:0.05488
# [525]	validation_0-rmse:0.05488
# Fold 27 RMSE: 0.0549
# Feature engineering & training time: 21.7 sec
#
# ########## Fold 28 ##########
# [0]	validation_0-rmse:0.93881
# [100]	validation_0-rmse:0.14005
# [200]	validation_0-rmse:0.06103
# [300]	validation_0-rmse:0.05830
# [400]	validation_0-rmse:0.05814
# [500]	validation_0-rmse:0.05813
# [527]	validation_0-rmse:0.05813
# Fold 28 RMSE: 0.0581
# Feature engineering & training time: 21.9 sec
#
# ########## Fold 29 ##########
# [0]	validation_0-rmse:0.94570
# [100]	validation_0-rmse:0.14422
# [200]	validation_0-rmse:0.06746
# [300]	validation_0-rmse:0.06480
# [400]	validation_0-rmse:0.06473
# [500]	validation_0-rmse:0.06474
# [520]	validation_0-rmse:0.06475
# Fold 29 RMSE: 0.0647
# Feature engineering & training time: 21.9 sec
#
# ########## Fold 30 ##########
# [0]	validation_0-rmse:0.95107
# [100]	validation_0-rmse:0.14145
# [200]	validation_0-rmse:0.06279
# [300]	validation_0-rmse:0.06053
# [400]	validation_0-rmse:0.06052
# [433]	validation_0-rmse:0.06053
# Fold 30 RMSE: 0.0605
# Feature engineering & training time: 18.2 sec
#
# ########## Fold 31 ##########
# [0]	validation_0-rmse:0.95377
# [100]	validation_0-rmse:0.14321
# [200]	validation_0-rmse:0.06351
# [300]	validation_0-rmse:0.06083
# [400]	validation_0-rmse:0.06077
# [465]	validation_0-rmse:0.06078
# Fold 31 RMSE: 0.0608
# Feature engineering & training time: 19.6 sec
#
# ########## Fold 32 ##########
# [0]	validation_0-rmse:0.93311
# [100]	validation_0-rmse:0.13761
# [200]	validation_0-rmse:0.05809
# [300]	validation_0-rmse:0.05550
# [400]	validation_0-rmse:0.05544
# [500]	validation_0-rmse:0.05545
# [559]	validation_0-rmse:0.05546
# Fold 32 RMSE: 0.0554
# Feature engineering & training time: 20.2 sec
#
# ########## Fold 33 ##########
# [0]	validation_0-rmse:0.94168
# [100]	validation_0-rmse:0.14165
# [200]	validation_0-rmse:0.06259
# [300]	validation_0-rmse:0.05977
# [400]	validation_0-rmse:0.05969
# [481]	validation_0-rmse:0.05971
# Fold 33 RMSE: 0.0597
# Feature engineering & training time: 19.8 sec
#
# ########## Fold 34 ##########
# [0]	validation_0-rmse:0.94186
# [100]	validation_0-rmse:0.13963
# [200]	validation_0-rmse:0.06187
# [300]	validation_0-rmse:0.05975
# [400]	validation_0-rmse:0.05976
# [425]	validation_0-rmse:0.05976
# Fold 34 RMSE: 0.0597
# Feature engineering & training time: 17.9 sec
#
# ########## Fold 35 ##########
# [0]	validation_0-rmse:0.94608
# [100]	validation_0-rmse:0.14040
# [200]	validation_0-rmse:0.06199
# [300]	validation_0-rmse:0.05971
# [400]	validation_0-rmse:0.05967
# [500]	validation_0-rmse:0.05971
# [543]	validation_0-rmse:0.05972
# Fold 35 RMSE: 0.0597
# Feature engineering & training time: 20.7 sec
#
# ########## Fold 36 ##########
# [0]	validation_0-rmse:0.94940
# [100]	validation_0-rmse:0.14052
# [200]	validation_0-rmse:0.06236
# [300]	validation_0-rmse:0.06038
# [400]	validation_0-rmse:0.06039
# [418]	validation_0-rmse:0.06038
# Fold 36 RMSE: 0.0603
# Feature engineering & training time: 18.5 sec
#
# ########## Fold 37 ##########
# [0]	validation_0-rmse:0.93765
# [100]	validation_0-rmse:0.14066
# [200]	validation_0-rmse:0.06092
# [300]	validation_0-rmse:0.05803
# [400]	validation_0-rmse:0.05784
# [496]	validation_0-rmse:0.05785
# Fold 37 RMSE: 0.0578
# Feature engineering & training time: 20.2 sec
#
# ########## Fold 38 ##########
# [0]	validation_0-rmse:0.94926
# [100]	validation_0-rmse:0.14241
# [200]	validation_0-rmse:0.06343
# [300]	validation_0-rmse:0.06085
# [400]	validation_0-rmse:0.06072
# [500]	validation_0-rmse:0.06074
# [543]	validation_0-rmse:0.06074
# Fold 38 RMSE: 0.0607
# Feature engineering & training time: 20.9 sec
#
# ########## Fold 39 ##########
# [0]	validation_0-rmse:0.93369
# [100]	validation_0-rmse:0.13945
# [200]	validation_0-rmse:0.06177
# [300]	validation_0-rmse:0.05937
# [400]	validation_0-rmse:0.05935
# [428]	validation_0-rmse:0.05936
# Fold 39 RMSE: 0.0593
# Feature engineering & training time: 18.8 sec
#
# ########## Fold 40 ##########
# [0]	validation_0-rmse:0.95241
# [100]	validation_0-rmse:0.14552
# [200]	validation_0-rmse:0.06818
# [300]	validation_0-rmse:0.06525
# [400]	validation_0-rmse:0.06501
# [500]	validation_0-rmse:0.06502
# [516]	validation_0-rmse:0.06502
# Fold 40 RMSE: 0.0650
# Feature engineering & training time: 20.8 sec
#
# ########## Fold 41 ##########
# [0]	validation_0-rmse:0.93505
# [100]	validation_0-rmse:0.14028
# [200]	validation_0-rmse:0.06166
# [300]	validation_0-rmse:0.05898
# [400]	validation_0-rmse:0.05892
# [467]	validation_0-rmse:0.05895
# Fold 41 RMSE: 0.0589
# Feature engineering & training time: 18.4 sec
#
# ########## Fold 42 ##########
# [0]	validation_0-rmse:0.93862
# [100]	validation_0-rmse:0.13789
# [200]	validation_0-rmse:0.05945
# [300]	validation_0-rmse:0.05727
# [400]	validation_0-rmse:0.05725
# [485]	validation_0-rmse:0.05727
# Fold 42 RMSE: 0.0572
# Feature engineering & training time: 19.9 sec
#
# ########## Fold 43 ##########
# [0]	validation_0-rmse:0.94370
# [100]	validation_0-rmse:0.14026
# [200]	validation_0-rmse:0.06152
# [300]	validation_0-rmse:0.05913
# [400]	validation_0-rmse:0.05906
# [500]	validation_0-rmse:0.05902
# [600]	validation_0-rmse:0.05897
# [700]	validation_0-rmse:0.05896
# [800]	validation_0-rmse:0.05896
# [814]	validation_0-rmse:0.05897
# Fold 43 RMSE: 0.0589
# Feature engineering & training time: 23.7 sec
#
# ########## Fold 44 ##########
# [0]	validation_0-rmse:0.94007
# [100]	validation_0-rmse:0.14186
# [200]	validation_0-rmse:0.06316
# [300]	validation_0-rmse:0.06039
# [400]	validation_0-rmse:0.06026
# [500]	validation_0-rmse:0.06025
# [579]	validation_0-rmse:0.06027
# Fold 44 RMSE: 0.0602
# Feature engineering & training time: 20.2 sec
#
# ########## Fold 45 ##########
# [0]	validation_0-rmse:0.94591
# [100]	validation_0-rmse:0.14240
# [200]	validation_0-rmse:0.06512
# [300]	validation_0-rmse:0.06261
# [400]	validation_0-rmse:0.06247
# [500]	validation_0-rmse:0.06248
# [506]	validation_0-rmse:0.06247
# Fold 45 RMSE: 0.0625
# Feature engineering & training time: 19.8 sec
#
# ########## Fold 46 ##########
# [0]	validation_0-rmse:0.95547
# [100]	validation_0-rmse:0.14054
# [200]	validation_0-rmse:0.05972
# [300]	validation_0-rmse:0.05748
# [400]	validation_0-rmse:0.05757
# [420]	validation_0-rmse:0.05759
# Fold 46 RMSE: 0.0575
# Feature engineering & training time: 17.3 sec
#
# ########## Fold 47 ##########
# [0]	validation_0-rmse:0.94530
# [100]	validation_0-rmse:0.14359
# [200]	validation_0-rmse:0.06416
# [300]	validation_0-rmse:0.06113
# [400]	validation_0-rmse:0.06087
# [500]	validation_0-rmse:0.06086
# [583]	validation_0-rmse:0.06090
# Fold 47 RMSE: 0.0608
# Feature engineering & training time: 21.0 sec
#
# ########## Fold 48 ##########
# [0]	validation_0-rmse:0.94226
# [100]	validation_0-rmse:0.14183
# [200]	validation_0-rmse:0.06350
# [300]	validation_0-rmse:0.06097
# [400]	validation_0-rmse:0.06082
# [500]	validation_0-rmse:0.06080
# [600]	validation_0-rmse:0.06082
# [625]	validation_0-rmse:0.06081
# Fold 48 RMSE: 0.0608
# Feature engineering & training time: 22.4 sec
#
# ########## Fold 49 ##########
# [0]	validation_0-rmse:0.95342
# [100]	validation_0-rmse:0.14210
# [200]	validation_0-rmse:0.06150
# [300]	validation_0-rmse:0.05887
# [400]	validation_0-rmse:0.05874
# [500]	validation_0-rmse:0.05870
# [563]	validation_0-rmse:0.05869
# Fold 49 RMSE: 0.0587
# Feature engineering & training time: 20.0 sec
#
# ########## Fold 50 ##########
# [0]	validation_0-rmse:0.94667
# [100]	validation_0-rmse:0.14158
# [200]	validation_0-rmse:0.06071
# [300]	validation_0-rmse:0.05775
# [400]	validation_0-rmse:0.05762
# [500]	validation_0-rmse:0.05766
# [502]	validation_0-rmse:0.05766
# Fold 50 RMSE: 0.0576
# Feature engineering & training time: 19.7 sec
#
# Final CV RMSE: 0.0598

# %%
# Analysis & Generate submission
y_preds = np.expm1(pred)
print('predict mean :',y_preds.mean())
print('predict median :',np.median(y_preds))

y_preds = np.clip(y_preds,1,314)
print('predict mean after clip:',y_preds.mean())
print('predict median after clip:',np.median(y_preds))

submission["Calories"] = y_preds
submission.to_csv("xbgv2_submission_1.csv", index=False)
submission.head()
# Out:
# predict mean : 88.15055037742071
# predict median : 76.41292912359289
# predict mean after clip: 88.15055037742071
# predict median after clip: 76.41292912359289
#        id    Calories
# 0  750000   27.433538
# 1  750001  107.891647
# 2  750002   87.805718
# 3  750003  125.802524
# 4  750004   75.816528
